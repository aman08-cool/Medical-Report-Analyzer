# %%
from transformers import pipeline
import pandas as pd

df = pd.read_csv("../data/medical_transcription.csv")

summarizer = pipeline(
    "summarization",
    model="facebook/bart-large-cnn",
    framework="pt"   # <-- THIS LINE MATTERS
)
# Out:
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading: 0.00B [00:00, ?B/s]
# Downloading: 0.00B [00:00, ?B/s]
# Downloading: 0.00B [00:00, ?B/s]

# %%
def summarize_report(text):
    word_count = len(text.split())

    if word_count < 50:
        return text  # already short, no need to summarize

    max_len = min(120, word_count // 2)
    min_len = min(50, max_len - 10)

    summary = summarizer(
        text,
        max_length=max_len,
        min_length=min_len,
        do_sample=False
    )

    return summary[0]["summary_text"]

# %%
DISCLAIMER = (
    "This summary is for informational purposes only "
    "and does not constitute medical advice or diagnosis."
)

# %%
text = df["transcription"].iloc[0]

final_output = summarize_report(text) + "\n\n" + DISCLAIMER
print(final_output)
# Out:
# A 23-year-old white female presents with complaint of allergies. She used to have allergies when she lived in Seattle but she thinks they are worse here. In the past, she has tried Claritin, and Zyrtec. Both worked for short time but then seemed to lose effectiveness.
#
# This summary is for informational purposes only and does not constitute medical advice or diagnosis.
